# %%
from keras.applications import VGG16

conv_base = VGG16(
    weights='imagenet',
)

# %%
import tensorflow as tf
import numpy as np
image = tf.keras.preprocessing.image.load_img(target_size=(224, 224), path='thumb-5c820a67460f1_568x568.jpg')
input_arr = keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])
yhat = conv_base.predict(input_arr)
# conv_base.predict('thumb-5c820a67460f1_568x568.jpg')

# %%
from keras.applications.vgg16 import decode_predictions
label = decode_predictions(yhat)
label = label[0][0]
print(label)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 40960/35363 [==================================] - 0s 0us/step
# ('n03063599', 'coffee_mug', 0.7500685)
